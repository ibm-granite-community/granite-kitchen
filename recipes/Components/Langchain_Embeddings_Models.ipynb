# %% [markdown]
# # Embeddings Models with Langchain
#
# In this recipe, we show how to obtain an embeddings model client for different providers using Langchain.

# %%
# %pip install git+https://github.com/ibm-granite-community/utils.git \
    langchain_huggingface sentence_transformers

# %% [markdown]
# ### HuggingFace
#
# You can use the `langchain_huggingface` package to obtain Granite embeddings models.

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings_model = HuggingFaceEmbeddings(model_name="ibm-granite/granite-embedding-small-english-r2")
